# %%
import sys

# %%
sys.path
# Out:
# ['/Users/crmarsh/Library/Application Support/uv/python/cpython-3.12.6-macos-aarch64-none/lib/python312.zip',
#  '/Users/crmarsh/Library/Application Support/uv/python/cpython-3.12.6-macos-aarch64-none/lib/python3.12',
#  '/Users/crmarsh/Library/Application Support/uv/python/cpython-3.12.6-macos-aarch64-none/lib/python3.12/lib-dynload',
#  '',
#  '/Users/crmarsh/.cache/uv/archive-v0/RUqtr-_FWH7hMVNmkRqca/lib/python3.12/site-packages']

# %%
# !uv pip install requests
# Out:
# Resolved 5 packages in 2ms
# Installed 5 packages in 3ms3.3.2
#  + certifi==2024.8.30
#  + charset-normalizer==3.3.2
#  + idna==3.10
#  + requests==2.32.3
#  + urllib3==2.2.3

# %%
# !uv pip install pydantic --verbose
# Out:
# DEBUG uv 0.4.15
# DEBUG Searching for default Python interpreter in system path
# DEBUG Found `cpython-3.12.6-macos-aarch64-none` at `/Users/crmarsh/.cache/uv/builds-v0/.tmpfY1zAp/bin/python3` (active virtual environment)
# DEBUG Using Python 3.12.6 environment at /Users/crmarsh/.cache/uv/builds-v0/.tmpfY1zAp/bin/python3
# DEBUG Acquired lock for `/Users/crmarsh/.cache/uv/builds-v0/.tmpfY1zAp`
# DEBUG At least one requirement is not satisfied: pydantic
# DEBUG Using request timeout of 30s
# DEBUG Solving with installed Python version: 3.12.6
# DEBUG Solving with target Python version: >=3.12.6
# DEBUG Adding direct dependency: pydantic*
# DEBUG No cache entry for: https://pypi.org/simple/pydantic/
# DEBUG Searching for a compatible version of pydantic (*)
# DEBUG Selecting: pydantic==2.9.2 [compatible] (pydantic-2.9.2-py3-none-any.whl)
# ...

# %%
import pydantic
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import pydantic
#
# ModuleNotFoundError: No module named 'pydantic'
